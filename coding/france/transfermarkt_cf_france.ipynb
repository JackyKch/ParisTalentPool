# %% [markdown]
# # Transfermarkt scrapping with Beautiful Soup & Selenium

# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %% [markdown]
# ## Webdriver options

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
#options.add_argument('--headless')

driver = webdriver.Chrome("../chromedriver-mac-arm64/chromedriver",options= options)
# Out:
# /var/folders/qw/qjxyt3tn1057c6j4pl5tb03c0000gn/T/ipykernel_27524/3657650218.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../chromedriver-mac-arm64/chromedriver",options= options)

# %% [markdown]
# ## Create dataframes and scrap the data from Transfermarkt

# %%
df_1985 = pd.DataFrame()
df_1986 = pd.DataFrame()
df_1987 = pd.DataFrame()
df_1988 = pd.DataFrame()
df_1989 = pd.DataFrame()
df_1990 = pd.DataFrame()
df_1991 = pd.DataFrame()
df_1992 = pd.DataFrame()
df_1993 = pd.DataFrame()
df_1994 = pd.DataFrame()
df_1995 = pd.DataFrame()
df_1996 = pd.DataFrame()
df_1997 = pd.DataFrame()
df_1998 = pd.DataFrame()
df_1999 = pd.DataFrame()
df_2000 = pd.DataFrame()
df_2001 = pd.DataFrame()
df_2002 = pd.DataFrame()
df_2003 = pd.DataFrame()
df_2004 = pd.DataFrame()
df_2005 = pd.DataFrame()

# %%
driver.get("https://www.transfermarkt.com/detailsuche/spielerdetail/suche/46762278/page/1")
page_source = driver.page_source
rows = []
next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
count = 2

#print(len(next_buttons))

#for x in range(len(next_buttons)):
while (len(next_buttons)!=0) :
    
    if next_buttons[0].is_displayed():

        soup = BeautifulSoup(page_source, "html.parser")
        #next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
        tables = soup.find_all('table')
        table = soup.find('table', class_ = 'items')  
      
        #Collect data for odd rows  
        for row in table.tbody.find_all('tr', class_="odd"):    
        # Find all data for each column
            columns = row.find_all('td')
    
            if(columns != []):

                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
            } )

        #Collect data for even rows
        for row in table.tbody.find_all('tr', class_="even"):    
        # Find all data for each column
            columns = row.find_all('td')
    
            if(columns != []):

                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
            } )        


        #driver.execute_script("arguments[0].click();", next_buttons[x])
        driver.get("https://www.transfermarkt.com/detailsuche/spielerdetail/suche/46762278/page/" + "" + str(count))
        page_source = driver.page_source
        next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
        count +=1


page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")
#next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
tables = soup.find_all('table')
table = soup.find('table', class_ = 'items')  
      
#Collect data for odd rows        
for row in table.tbody.find_all('tr', class_="odd"):    
    # Find all data for each column
    columns = row.find_all('td')
    
    if(columns != []):
                
                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
    } )

#Collect data for even rows
for row in table.tbody.find_all('tr', class_="even"):    
    # Find all data for each column
    columns = row.find_all('td')
    
    if(columns != []):
                
                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
    } )  

df_2005 = pd.DataFrame(rows)               
df_2005
# Out:
#    Number                       Name        Position  Date of Birth Age
# 0      20                 Andy Logbo  Centre-Forward   May 6, 2004   19  \
# 1      30                 Yonis Njoh  Centre-Forward  Jan 17, 2004   20
# 2                 Djibril Diagouraga  Centre-Forward  Oct 11, 2004   19
# 3      93             Breyton Fougeu  Centre-Forward   Jan 6, 2004   20
# 4       9              Eliott Labeth  Centre-Forward  Mar 22, 2004   19
# 5               Raphaël N'Semi Segui  Centre-Forward  Oct 24, 2004   19
# 6                       Modibo Keïta  Centre-Forward  Feb 18, 2004   20
# 7                        Axel Monnet  Centre-Forward  Jan 15, 2004   20
# 8                    Killian Kabamba  Centre-Forward  Dec 17, 2004   19
# 9                 Luc-Didier Oli Oro  Centre-Forward  May 29, 2004   19
# 10                       Sean Tormin  Centre-Forward  May 19, 2004   19
# 11                      Yannis Lagha  Centre-Forward  Jun 21, 2004   19
# 12     12          Mahamadou Kanouté  Centre-Forward  Jan 24, 2004   20
# 13      9            Amine Messoussa  Centre-Forward  Oct 12, 2004   19
# 14     19                David Mokwa  Centre-Forward   May 3, 2004   19
# 15                    Edvin Bongemba  Centre-Forward  Jan 14, 2004   20
# 16              Souleymane Coulibaly  Centre-Forward  Mar 27, 2004   19
# 17                     Charles Goyer  Centre-Forward  May 27, 2004   19
# 18     20             Amadou Thioune  Centre-Forward  Jun 12, 2004   19
# 19                      Mathis Moyen  Centre-Forward  Aug 25, 2004   19
# 20                    Ermin Alibasic  Centre-Forward   Nov 4, 2004   19
# 21                    Moïse Botulama  Centre-Forward  Feb 29, 2004   20
# 22         Aymeric Faurand-Tournaire  Centre-Forward  Apr 14, 2004   19
# 23                        Adel Bacha  Centre-Forward  May 17, 2004   19
# 24                     Wilson Samaké  Centre-Forward  Mar 30, 2004   19
# 25     15              Yad Lochereau  Centre-Forward   Feb 6, 2004   20
#
#                 Nationality Birth Country      Place of Birth Other Positions
# 0   [France, Cote d'Ivoire]        France               Paris                  \
# 1        [France, Cameroon]        France            Toulouse         LW   RW
# 2            [France, Mali]        France                Évry
# 3           [France, Congo]        France  Tremblay-en-France         RW   LW
# 4      [France, Guadeloupe]        France            Mulhouse         RW   LW
# 5   [France, Cote d'Ivoire]        France          Strasbourg         LW   RW
# 6            [France, Mali]        France
# 7         [France, Germany]        France                                  SS
# 8        [France, DR Congo]        France               Melun         LW   RW
# 9   [France, Cote d'Ivoire]        France               Paris
# 10     [France, Guadeloupe]        France               Paris
# 11        [Algeria, France]        France                Lyon
# 12           [France, Mali]        France               Paris
# 13        [France, Morocco]        France                Lyon         LW   RW
# 14       [France, DR Congo]        France            Bagnolet         AM   RW
# 15       [France, DR Congo]        France         Montpellier         LW   SS
# 16                 [France]        France              Parigi         SS   RW
# 17                 [France]        France              Grasse
# 18        [France, Senegal]        France          Le Chesnay              LW
# 19     [France, Martinique]        France
# 20                 [France]        France              Verdun
# 21       [France, DR Congo]        France               Paris         LW   RW
# 22        [France, Vietnam]        France                             SS   RW
# 23        [France, Algeria]        France            Nanterre              SS
# 24           [France, Mali]        France     Vitry-sur-Seine              RW
# 25        [France, Algeria]        France                Évry         RW   LW
#
#    Height Market Value
# 0    1,88        €800k
# 1    1,85        €200k
# 2                 €50k
# 3    1,75         €50k
# 4    1,80            -
# 5    1,84            -
# 6    1,78            -
# 7                    -
# 8    1,77            -
# 9    1,87            -
# 10   1,76            -
# 11   1,85            -
# 12   1,90            -
# 13   1,80        €400k
# 14   1,80        €125k
# 15   1,88         €50k
# 16   1,86         €25k
# 17   1,80            -
# 18   1,87            -
# 19   1,79            -
# 20                   -
# 21   1,86            -
# 22   1,81            -
# 23   1,70            -
# 24                   -
# 25   1,78            -

# %%
with pd.option_context('display.max_rows',None, 'display.max_columns',None):print(df_2001)
# Out:
#    Number                     Name        Position  Date of Birth Age
# 0      29           Evann Guessand  Centre-Forward   Jul 1, 2001   22  \
# 1       9          Willem Geubbels  Centre-Forward  Aug 16, 2001   22
# 2      70             Evans Maurin  Centre-Forward  Mar 30, 2001   22
# 3       9      Lamine Diaby-Fadiga  Centre-Forward  Jan 19, 2001   23
# 4      11             Amadou Ba-Sy  Centre-Forward   Jun 8, 2001   22
# 5      21           Mehdi Baaloudj  Centre-Forward   Feb 2, 2001   23
# 6      88         Yanis Guermouche  Centre-Forward  Apr 15, 2001   22
# 7                     Darell Tokpa  Centre-Forward   Jun 2, 2001   22
# 8                      Nabil Makni  Centre-Forward  Sep 29, 2001   22
# 9      19              Ilies Faure  Centre-Forward  Jun 28, 2001   22
# 10                Oscar Le Guillou  Centre-Forward  Oct 18, 2001   22
# 11                 Antoine Coquant  Centre-Forward   Dec 3, 2001   22
# 12             Loïc Amisi Kasabala  Centre-Forward  Nov 16, 2001   22
# 13      9        Amine El Ouazzani  Centre-Forward  Jul 15, 2001   22
# 14      9           Yanis Begraoui  Centre-Forward   Jul 4, 2001   22
# 15     19           Samuel Ntamack  Centre-Forward  Apr 27, 2001   22
# 16      9            Noha Ndombasi  Centre-Forward  Apr 28, 2001   22
# 17     19            Nesta Elphege  Centre-Forward   Jan 9, 2001   23
# 18     17             Jacques Siwe  Centre-Forward  Jul 29, 2001   22
# 19     20        Ulrick Eneme-Ella  Centre-Forward  May 22, 2001   22
# 20     18         Franck Rivollier  Centre-Forward  Apr 20, 2001   22
# 21                     Yann Fangwa  Centre-Forward  Jan 24, 2001   23
# 22     25              Kévin Mbala  Centre-Forward  Jan 17, 2001   23
# 23                 Isoumail Camara  Centre-Forward   Nov 3, 2001   22
# 24                      Jean Boyer  Centre-Forward  Mar 11, 2001   22
# 25         Olivier Cassange Nzimbu  Centre-Forward   Aug 8, 2001   22
# 26     77       Mehdi Dan Galibali  Centre-Forward   Jan 4, 2001   23
# 27                      Enzo Renou  Centre-Forward  Aug 20, 2001   22
# 28                     Jilo Niamké  Centre-Forward  Sep 17, 2001   22
# 29                   Sacha Hamache  Centre-Forward   Jan 5, 2001   23
# 30                   Steevy Nogbou  Centre-Forward  Apr 27, 2001   22
# 31                     Hugo Danjou  Centre-Forward  Mar 12, 2001   22
# 32                  Dylan Dalmasso  Centre-Forward  Jan 31, 2001   23
# 33                  Ibrahim Carlak  Centre-Forward  Nov 21, 2001   22
# 34     30        Sofiane El Ftouhi  Centre-Forward  Jan 26, 2001   23
# 35                     Steven Goma  Centre-Forward  Nov 15, 2001   22
# 36                 Wilfried Misiak  Centre-Forward   Oct 6, 2001   22
# 37     28            Isyakha Touré  Centre-Forward   Feb 2, 2001   23
# 38                   Maxence Puget  Centre-Forward   Mar 2, 2001   23
# 39                  Thomas Gautier  Centre-Forward  Jul 25, 2001   22
# 40            Mamadou Saliou Dramé  Centre-Forward  Dec 28, 2001   22
# 41     22              Thomas Gret  Centre-Forward  May 15, 2001   22
# 42     22              Daniel Glao  Centre-Forward  Sep 14, 2001   22
# 43                 Précieux N'Kaba  Centre-Forward  Mar 28, 2001   22
# 44                    Paul Bonneau  Centre-Forward   Jun 6, 2001   22
# 45     15       Gamil Abdourazakou  Centre-Forward  May 16, 2001   22
# 46                     Emrys Gomis  Centre-Forward   Oct 1, 2001   22
# 47     12               Axel Gnapi  Centre-Forward  Aug 28, 2001   22
# 48                     Elie Kisoka  Centre-Forward   Dec 8, 2001   22
# 49     14           Jordan Pothier  Centre-Forward   Feb 9, 2001   23
# 50                    Sami Messili  Centre-Forward  Nov 19, 2001   22
# 51     19               Enzo Daoud  Centre-Forward   Apr 2, 2001   22
# 52                  Norvin Mukiele  Centre-Forward  Feb 16, 2001   23
# 53     26             El Hadj Coly  Centre-Forward   Jul 5, 2001   22
# 54               Ridge Duah-Adusei  Centre-Forward  Mar 10, 2001   22
# 55             Aboubaker Es Sahhal  Centre-Forward  Jan 29, 2001   23
# 56                 Loïck Piquionne  Centre-Forward  Apr 17, 2001   22
# 57                   Sacha Guilhen  Centre-Forward  Mar 26, 2001   22
# 58                Giovann Couasnon  Centre-Forward   Apr 5, 2001   22
# 59              Méroine El Hammiri  Centre-Forward  May 23, 2001   22
# 60                  Nathan Malonga  Centre-Forward  Jan 15, 2001   23
# 61                     Yohan Greco  Centre-Forward   Jan 7, 2001   23
# 62                    Sonny Contri  Centre-Forward  Dec 19, 2001   22
# 63                    Yacine Ressa  Centre-Forward  Apr 11, 2001   22
#
#                 Nationality Birth Country            Place of Birth
# 0   [Cote d'Ivoire, France]        France                   Ajaccio  \
# 1     [France, Netherlands]        France              Villeurbanne
# 2                  [France]        France                 Charenton
# 3          [France, Guinea]        France                    Grasse
# 4         [France, Senegal]        France                      Nice
# 5         [Algeria, France]        France                     Melun
# 6         [Algeria, France]        France         Neuilly-sur-Seine
# 7   [France, Cote d'Ivoire]        France                  Colombes
# 8         [Tunisia, France]        France                    Cannes
# 9         [France, Algeria]        France                  Toulouse
# 10                 [France]        France                    Rennes
# 11                 [France]        France                      Nice
# 12                 [France]        France
# 13        [Morocco, France]        France                  Grenoble
# 14        [Morocco, France]        France                   Étampes
# 15       [France, Cameroon]        France                 Montreuil
# 16                 [France]        France                     Bondy
# 17       [France, Cameroon]        France               Saint-Denis
# 18       [France, Cameroon]        France             Saint-Maurice
# 19          [Gabon, France]        France                      Sens
# 20       [France, Cameroon]        France             Saint-Étienne
# 21                 [France]        France
# 22       [France, DR Congo]        France  Villeneuve-Saint-Georges
# 23                 [France]        France                 Compiègne
# 24                 [France]        France             Castelnaudary
# 25                 [France]        France                      Lyon
# 26          [France, Congo]        France                  Pontoise
# 27                 [France]        France               La Rochelle
# 28  [France, Cote d'Ivoire]        France                     Paris
# 29        [France, Algeria]        France                     Croix
# 30                 [France]        France                    Clichy
# 31                 [France]        France      Saint-Jean-de-Verges
# 32                 [France]        France
# 33                [Türkiye]        France         Mont-Saint-Martin
# 34        [France, Morocco]        France                 Perpignan
# 35                 [France]        France            Roissy-en-Brie
# 36         [France, Poland]        France                     Melun
# 37           [France, Mali]        France                 Montreuil
# 38                 [France]        France
# 39                 [France]        France                     Paris
# 40                 [France]        France                      Nice
# 41                 [France]        France  Saint-Julien-en-Genevois
# 42  [France, Cote d'Ivoire]        France                 Montreuil
# 43          [France, Congo]        France             Aubervilliers
# 44                 [France]        France                      Auch
# 45                 [France]        France                    Nantes
# 46        [France, Senegal]        France    Saint-Aubin-lès-Elbeuf
# 47  [France, Cote d'Ivoire]        France                   Le Mans
# 48       [France, DR Congo]        France                     Lille
# 49                 [France]        France                 Périgueux
# 50        [France, Algeria]        France    Le Chambon-Feugerolles
# 51        [France, Algeria]        France                      Lens
# 52       [France, DR Congo]        France
# 53        [France, Senegal]        France                La Tronche
# 54                 [France]        France                     Melun
# 55        [France, Morocco]        France               Montpellier
# 56     [France, Martinique]        France                    Rennes
# 57                 [France]        France                      Sète
# 58                 [France]        France
# 59        [France, Morocco]        France           Le Puy-en-Velay
# 60                 [France]        France                   Trappes
# 61          [France, Italy]        France                      Lyon
# 62                 [France]        France                 Marseille
# 63        [Algeria, France]        France                 Marseille
#
#    Other Positions Height Market Value
# 0          RW   LW   1,88       €5.00m
# 1          RW   LW   1,85       €2.00m
# 2               AM   1,79        €400k
# 3                    1,88        €400k
# 4                    1,91        €300k
# 5          SS   LW   1,83        €300k
# 6                    1,92        €150k
# 7                    1,84        €100k
# 8               LW   1,84         €75k
# 9                    1,92         €50k
# 10                                   -
# 11                                   -
# 12         LW   RW                   -
# 13              AM   1,88       €2.00m
# 14         RW   LW   1,79       €1.00m
# 15         LW   RW   1,78        €400k
# 16         RW   LW   1,74        €400k
# 17                   1,96        €300k
# 18                   1,83        €200k
# 19                   1,84        €150k
# 20              RW   1,92        €100k
# 21                   1,90         €75k
# 22                   1,90         €50k
# 23         RW   LW   1,85            -
# 24         RW   SS   1,83            -
# 25                   1,87            -
# 26         LW   RW   1,87            -
# 27                                   -
# 28         SS   RW   1,75            -
# 29         RW   RM   1,76            -
# 30                                   -
# 31                                   -
# 32                   1,80            -
# 33                   1,85            -
# 34                   1,82            -
# 35              LW   1,83            -
# 36         RW   LW   1,85            -
# 37         RW   LW                   -
# 38              AM   1,87            -
# 39                   1,93            -
# 40         LW   RW   1,76            -
# 41                                   -
# 42         RW   LW   1,85            -
# 43              LW   1,84            -
# 44                                   -
# 45         LW   RW   1,83            -
# 46              LM                   -
# 47                   1,86            -
# 48                   1,80            -
# 49         RW   LW                   -
# 50         RW   LW   1,67            -
# 51                   1,83            -
# 52                   1,91            -
# 53         RW   LW   1,76            -
# 54         RW   LW                   -
# 55         SS   LW   1,80            -
# 56                   1,84            -
# 57         LW   RW   1,78            -
# 58              AM   1,76            -
# 59         RW   LW   1,72            -
# 60         LW   RW   1,78            -
# 61                   1,72            -
# 62                                   -
# 63                   1,88            -

# %% [markdown]
# ## Merge all the dataframes into a single one and save the df into a csv file

# %%
df_merged = pd.concat([df_1985,df_1986,df_1987,df_1988,df_1989,df_1990,df_1991,df_1992,df_1993,df_1994,df_1995,df_1996,df_1997,df_1998,df_1999,df_2000,df_2001,df_2002,df_2003,df_2004,df_2005],ignore_index=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Number           436 non-null    object
#  1   Name             436 non-null    object
#  2   Position         436 non-null    object
#  3   Date of Birth    436 non-null    object
#  4   Age              436 non-null    object
#  5   Nationality      436 non-null    object
#  6   Birth Country    436 non-null    object
#  7   Place of Birth   436 non-null    object
#  8   Other Positions  436 non-null    object
#  9   Height           436 non-null    object
#  10  Market Value     436 non-null    object
# dtypes: object(11)
# memory usage: 37.6+ KB

# %%
df_merged.to_csv("../../data/france_centerforwards.csv", header= True, index=False)

# %%
df_merged
# Out:
#     Number              Name      Position  Date of Birth Age
# 0        7        Riad Nouri  Right Winger   Jun 7, 1985   38  \
# 1              Cyril Bagnost  Right Winger  Jan 24, 1985   39
# 2           Damien Boudjemaa  Right Winger   Jun 7, 1985   38
# 3            Benjamin Psaume  Right Winger  Jan 12, 1985   39
# 4              Virgile Reset  Right Winger   Aug 3, 1985   38
# ..     ...               ...           ...            ...  ..
# 431          Kiliann Marquet  Right Winger  Apr 15, 2005   18
# 432             Enzo Cantero  Right Winger  May 15, 2005   18
# 433            Lenny Lankoso  Right Winger  Jun 23, 2005   18
# 434            Benoît Dureux  Right Winger  Jun 10, 2005   18
# 435            Kelyan Hamadi  Right Winger   Dec 7, 2005   18
#
#             Nationality Birth Country       Place of Birth Other Positions
# 0     [France, Algeria]        France            Marseille         LW   CF  \
# 1              [France]        France              Epernay              LW
# 2     [France, Algeria]        France                Paris         AM   CM
# 3              [France]        France                 Auch         LW   CF
# 4              [France]        France                Lilas              LW
# ..                  ...           ...                  ...             ...
# 431     [France, Italy]        France      Aix-en-Provence         LW   CF
# 432            [France]        France  Sainte-Foy-lès-Lyon
# 433  [France, DR Congo]        France    Beaumont-sur-Oise              AM
# 434            [France]        France         Valenciennes              RM
# 435   [Comoros, France]        France            Marseille         LW   AM
#
#     Height Market Value
# 0     1,78        €200k
# 1     1,75            -
# 2     1,73            -
# 3     1,70            -
# 4     1,75            -
# ..     ...          ...
# 431   1,84            -
# 432   1,65            -
# 433                   -
# 434                   -
# 435   1,74            -
#
# [436 rows x 11 columns]
