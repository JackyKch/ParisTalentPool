# %% [markdown]
# # Transfermarkt scrapping with Beautiful Soup & Selenium

# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %% [markdown]
# ## Webdriver options

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
#options.add_argument('--headless')

driver = webdriver.Chrome("../chromedriver-mac-arm64/chromedriver",options= options)
# Out:
# /var/folders/qw/qjxyt3tn1057c6j4pl5tb03c0000gn/T/ipykernel_24048/3657650218.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../chromedriver-mac-arm64/chromedriver",options= options)

# %% [markdown]
# ## Create dataframes and scrap the data from Transfermarkt

# %%
df_1985 = pd.DataFrame()
df_1986 = pd.DataFrame()
df_1987 = pd.DataFrame()
df_1988 = pd.DataFrame()
df_1989 = pd.DataFrame()
df_1990 = pd.DataFrame()
df_1991 = pd.DataFrame()
df_1992 = pd.DataFrame()
df_1993 = pd.DataFrame()
df_1994 = pd.DataFrame()
df_1995 = pd.DataFrame()
df_1996 = pd.DataFrame()
df_1997 = pd.DataFrame()
df_1998 = pd.DataFrame()
df_1999 = pd.DataFrame()
df_2000 = pd.DataFrame()
df_2001 = pd.DataFrame()
df_2002 = pd.DataFrame()
df_2003 = pd.DataFrame()
df_2004 = pd.DataFrame()
df_2005 = pd.DataFrame()

# %%
driver.get("https://www.transfermarkt.com/detailsuche/spielerdetail/suche/46762278/page/1")
page_source = driver.page_source
rows = []
next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
count = 2

#print(len(next_buttons))

#for x in range(len(next_buttons)):
while (len(next_buttons)!=0) :
    
    if next_buttons[0].is_displayed():

        soup = BeautifulSoup(page_source, "html.parser")
        #next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
        tables = soup.find_all('table')
        table = soup.find('table', class_ = 'items')  
      
        #Collect data for odd rows  
        for row in table.tbody.find_all('tr', class_="odd"):    
        # Find all data for each column
            columns = row.find_all('td')
    
            if(columns != []):

                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
            } )

        #Collect data for even rows
        for row in table.tbody.find_all('tr', class_="even"):    
        # Find all data for each column
            columns = row.find_all('td')
    
            if(columns != []):

                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
            } )        


        #driver.execute_script("arguments[0].click();", next_buttons[x])
        driver.get("https://www.transfermarkt.com/detailsuche/spielerdetail/suche/46762278/page/" + "" + str(count))
        page_source = driver.page_source
        next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
        count +=1


page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")
#next_buttons = driver.find_elements(By.XPATH,"//a [@title='Go to the next page']")
tables = soup.find_all('table')
table = soup.find('table', class_ = 'items')  
      
#Collect data for odd rows        
for row in table.tbody.find_all('tr', class_="odd"):    
    # Find all data for each column
    columns = row.find_all('td')
    
    if(columns != []):
                
                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
    } )

#Collect data for even rows
for row in table.tbody.find_all('tr', class_="even"):    
    # Find all data for each column
    columns = row.find_all('td')
    
    if(columns != []):
                
                nationalities=[]
                for nationality in columns[6]:
                    if nationality.get("title") is not None :
                        nationalities.append(nationality.get("title"))

                rows.append({
                'Number' : columns[0].text.strip(),
                'Name':columns[3].text.strip(),
                'Position': columns[4].text.strip(),
                'Date of Birth': columns[5].text.split('(')[0],
                'Age': columns[5].text.split('(')[-1].replace(")",''),
                'Nationality': nationalities ,
                'Birth Country': 'France',
                'Place of Birth': columns[8].text.strip(),
                'Other Positions' : columns[9].text.strip(),
                'Height' : columns[10].text.strip(),
                'Market Value' : columns[11].text.strip()
    } )  

df_2002 = pd.DataFrame(rows)               
df_2002
# Out:
#    Number                       Name      Position  Date of Birth Age
# 0      21             Haissem Hassan  Right Winger   Feb 8, 2002   22  \
# 1       9              Junior Kadile  Right Winger  Dec 16, 2002   21
# 2      23    Logan Delaurier-Chaubet  Right Winger  Apr 22, 2002   21
# 3       9               Kelian Nsona  Right Winger  May 11, 2002   21
# 4      23              Amadou Traoré  Right Winger   Mar 7, 2002   22
# 5      15                Alban Alima  Right Winger  Oct 18, 2002   21
# 6                   Anthony Gardette  Right Winger   May 1, 2002   21
# 7      21               Kylian Tubio  Right Winger  Apr 18, 2002   21
# 8                     Junior N'Diefi  Right Winger  Dec 20, 2002   21
# 9                    Zinédine Ayachi  Right Winger  Jun 23, 2002   21
# 10                    Yanis Benahlal  Right Winger  Oct 30, 2002   21
# 11                     Karim Belmahi  Right Winger  Oct 18, 2002   21
# 12     14             Charles Costes  Right Winger  Sep 16, 2002   21
# 13     19              Isaac Lihadji  Right Winger  Apr 10, 2002   21
# 14     29            Farès Ghedjemis  Right Winger   Sep 6, 2002   21
# 15     17                 Noah Fatar  Right Winger  Feb 15, 2002   22
# 16     20             Maxence Rivera  Right Winger  May 30, 2002   21
# 17                      Djibrail Dib  Right Winger   Jul 3, 2002   21
# 18     19              Moussa Diallo  Right Winger  Nov 21, 2002   21
# 19                 Fouad Raho Moussa  Right Winger   Aug 4, 2002   21
# 20                     Ismail Essami  Right Winger   Jan 4, 2002   22
# 21                    Matéo De Jacob  Right Winger  Nov 30, 2002   21
# 22                      Thoma Boutin  Right Winger   Feb 4, 2002   22
# 23               Charles Keny Mayasi  Right Winger   Jan 2, 2002   22
# 24     17                  Emre Eren  Right Winger  Mar 22, 2002   21
# 25                  Kylian Silvestre  Right Winger  Aug 16, 2002   21
# 26                      Hervé Malebe  Right Winger  Feb 11, 2002   22
# 27     48               Shahin Maïri  Right Winger  Apr 25, 2002   21
# 28                 Jessim Pellissard  Right Winger   Nov 6, 2002   21
# 29         Kana Aguiedia Ali Kellian  Right Winger   Jan 1, 2002   22
# 30                      Joss Nkongue  Right Winger  Jan 18, 2002   22
# 31                Pierre-Noah Mabika  Right Winger   Mar 5, 2002   22
#
#                 Nationality Birth Country        Place of Birth
# 0           [France, Egypt]        France              Bagnolet  \
# 1                  [France]        France                Rennes
# 2                  [France]        France  Saint-Jean-de-Verges
# 3        [France, DR Congo]        France        Ivry-sur-Seine
# 4          [Guinea, France]        France                 Paris
# 5                  [France]        France                 Bondy
# 6           [France, Spain]        France                Cluses
# 7           [France, Spain]        France                Colmar
# 8        [France, Cameroon]        France  Charleville-Mézières
# 9         [France, Algeria]        France                  Lens
# 10        [France, Algeria]        France                 Dijon
# 11        [France, Algeria]        France                  Lyon
# 12  [France, Cote d'Ivoire]        France                 Paris
# 13        [France, Comoros]        France             Marseille
# 14        [France, Algeria]        France             Montreuil
# 15        [France, Morocco]        France           L'Isle-Adam
# 16                 [France]        France            Vénissieux
# 17        [Algeria, France]        France                  Lyon
# 18                 [France]        France
# 19        [France, Algeria]        France                  Metz
# 20        [France, Morocco]        France          Valenciennes
# 21                 [France]        France        Vaulx-en-Velin
# 22     [France, Luxembourg]        France              Lorraine
# 23       [France, DR Congo]        France      Clermont-Ferrand
# 24                [Türkiye]        France               Gonesse
# 25     [France, Guadeloupe]        France               Gonesse
# 26       [France, Cameroon]        France            Argenteuil
# 27        [France, Algeria]        France
# 28        [Algeria, France]        France              Besançon
# 29                 [France]        France                  Metz
# 30       [France, Cameroon]        France              Toulouse
# 31       [DR Congo, France]        France                 Paris
#
#    Other Positions Height Market Value
# 0               LW   1,75       €1.80m
# 1          LW   CF   1,80        €700k
# 2          LW   AM   1,73        €600k
# 3               LW   1,90        €500k
# 4               LW   1,77        €250k
# 5               RB   1,83            -
# 6          LW   CF                   -
# 7                                    -
# 8               RM   1,75            -
# 9               LW   1,75            -
# 10              LW   1,81            -
# 11              LW   1,74            -
# 12              LW   1,78            -
# 13              LW   1,77       €1.00m
# 14         AM   LW   1,83        €600k
# 15         CF   AM   1,70        €500k
# 16         LW   AM   1,68        €300k
# 17              AM   1,72        €150k
# 18                                   -
# 19         LW   SS                   -
# 20                   1,83            -
# 21                                   -
# 22              LW   1,75            -
# 23         LW   AM                   -
# 24              AM   1,82            -
# 25              LW   1,83            -
# 26         AM   LW   1,70            -
# 27         AM   LW   1,77            -
# 28         LW   CF   1,75            -
# 29                                   -
# 30              LW   1,80            -
# 31                   1,75            -

# %%
with pd.option_context('display.max_rows',None, 'display.max_columns',None):print(df_1986)
# Out:
#   Number             Name        Position  Date of Birth Age
# 0            Cyril Dalmat  Right Midfield   Oct 3, 1986   37  \
# 1           Khaled Gourmi  Right Midfield  Apr 18, 1986   37
# 2         Geoffrey Tréand  Right Midfield  Jan 16, 1986   38
# 3          Julien Chendri  Right Midfield  Aug 10, 1986   37
# 4           Marian Bănuță  Right Midfield  Aug 13, 1986   37
#
#             Nationality Birth Country Place of Birth Other Positions Height
# 0  [France, Martinique]        France          Tours                   1,74  \
# 1     [Algeria, France]        France          Paris         LM   AM   1,74
# 2              [France]        France      Annemasse         LM   AM   1,78
# 3              [France]        France    Villecrsnes                   1,70
# 4     [Romania, France]        France       Toulouse                   1,75
#
#   Market Value
# 0            -
# 1            -
# 2            -
# 3            -
# 4            -

# %% [markdown]
# ## Merge all the dataframes into a single one and save the df into a csv file

# %%
df_merged = pd.concat([df_1985,df_1986,df_1987,df_1988,df_1989,df_1990,df_1991,df_1992,df_1993,df_1994,df_1995,df_1996,df_1997,df_1998,df_1999,df_2000,df_2001,df_2002,df_2003,df_2004,df_2005],ignore_index=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Number           436 non-null    object
#  1   Name             436 non-null    object
#  2   Position         436 non-null    object
#  3   Date of Birth    436 non-null    object
#  4   Age              436 non-null    object
#  5   Nationality      436 non-null    object
#  6   Birth Country    436 non-null    object
#  7   Place of Birth   436 non-null    object
#  8   Other Positions  436 non-null    object
#  9   Height           436 non-null    object
#  10  Market Value     436 non-null    object
# dtypes: object(11)
# memory usage: 37.6+ KB

# %%
df_merged.to_csv("../../data/france_rightwingers.csv", header= True, index=False)

# %%
df_merged
# Out:
#     Number              Name      Position  Date of Birth Age
# 0        7        Riad Nouri  Right Winger   Jun 7, 1985   38  \
# 1              Cyril Bagnost  Right Winger  Jan 24, 1985   39
# 2           Damien Boudjemaa  Right Winger   Jun 7, 1985   38
# 3            Benjamin Psaume  Right Winger  Jan 12, 1985   39
# 4              Virgile Reset  Right Winger   Aug 3, 1985   38
# ..     ...               ...           ...            ...  ..
# 431          Kiliann Marquet  Right Winger  Apr 15, 2005   18
# 432             Enzo Cantero  Right Winger  May 15, 2005   18
# 433            Lenny Lankoso  Right Winger  Jun 23, 2005   18
# 434            Benoît Dureux  Right Winger  Jun 10, 2005   18
# 435            Kelyan Hamadi  Right Winger   Dec 7, 2005   18
#
#             Nationality Birth Country       Place of Birth Other Positions
# 0     [France, Algeria]        France            Marseille         LW   CF  \
# 1              [France]        France              Epernay              LW
# 2     [France, Algeria]        France                Paris         AM   CM
# 3              [France]        France                 Auch         LW   CF
# 4              [France]        France                Lilas              LW
# ..                  ...           ...                  ...             ...
# 431     [France, Italy]        France      Aix-en-Provence         LW   CF
# 432            [France]        France  Sainte-Foy-lès-Lyon
# 433  [France, DR Congo]        France    Beaumont-sur-Oise              AM
# 434            [France]        France         Valenciennes              RM
# 435   [Comoros, France]        France            Marseille         LW   AM
#
#     Height Market Value
# 0     1,78        €200k
# 1     1,75            -
# 2     1,73            -
# 3     1,70            -
# 4     1,75            -
# ..     ...          ...
# 431   1,84            -
# 432   1,65            -
# 433                   -
# 434                   -
# 435   1,74            -
#
# [436 rows x 11 columns]
